# %% [markdown]
# **IMPORT** **LIBRARIES**

# %%
#import required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# sets the backend of matplotlib to the 'inline' backend

# %% [markdown]
# **IMPORT** **DATASET**

# %%
eco = pd.read_csv('/content/AIMLPROJECT.csv')

# %%
eco.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
eco.tail()
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 57  12/31/2017        6.7954         3.3282    2651.472946
# 58  12/31/2018        6.4539         3.9388    2702.929719
# 59  12/31/2019        3.7379         3.7295    2831.552223
# 60  12/31/2020       -6.5961         6.6234    2667.687952
# 61  12/31/2021        8.6812         5.1314    3176.295065
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 57             498.258561             582.017724             5.330
# 58             538.635202             640.300825             5.270
# 59             529.244936             602.314912             7.997
# 60             499.095036             509.433826             5.978
# 61             679.680586             758.871890               NaN
#
#     CurrentAccountDeficit
# 57             -83.759163
# 58            -101.665624
# 59             -73.069975
# 60             -10.338790
# 61             -79.191303

# %%
eco[20:30]
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 20  12/31/1980        6.7358        11.3461     186.325345
# 21  12/31/1981        6.0062        13.1125     193.490610
# 22  12/31/1982        3.4757         7.8907     200.715145
# 23  12/31/1983        7.2889        11.8681     218.262273
# 24  12/31/1984        3.8207         8.3189     212.158234
# 25  12/31/1985        5.2543         5.5564     232.511878
# 26  12/31/1986        4.7766         8.7297     248.985994
# 27  12/31/1987        3.9654         8.8011     279.033584
# 28  12/31/1988        9.6278         9.3835     296.588995
# 29  12/31/1989        5.9473         7.0743     296.042355
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 20              11.439540              17.225826               NaN
# 21              11.485654              16.584541               NaN
# 22              12.009389              16.343487               NaN
# 23              12.741343              17.140059               NaN
# 24              13.330753              16.391291               NaN
# 25              12.217464              17.776652               NaN
# 26              12.937864              17.486411               NaN
# 27              15.638663              19.477195               NaN
# 28              17.899798              22.111393               NaN
# 29              20.770717              24.133378               NaN
#
#     CurrentAccountDeficit
# 20              -5.786286
# 21              -5.098887
# 22              -4.334098
# 23              -4.398716
# 24              -3.060538
# 25              -5.559187
# 26              -4.548547
# 27              -3.838532
# 28              -4.211595
# 29              -3.362661

# %% [markdown]
# **DATA CLEANING**

# %%
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   62 non-null     object
#  1   GDPGrothRate           62 non-null     float64
#  2   InflationRate          62 non-null     float64
#  3   GDPBillionUSD          62 non-null     float64
#  4   ExportValueBillionUSD  62 non-null     float64
#  5   ImportValueBillionUSD  62 non-null     float64
#  6   UnemploymentRate       30 non-null     float64
#  7   CurrentAccountDeficit  62 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 4.0+ KB

# %%
eco.index
# Out:
# RangeIndex(start=0, stop=62, step=1)

# %%
eco.columns
# Out:
# Index(['DATE', 'GDPGrothRate', 'InflationRate', 'GDPBillionUSD',
#        'ExportValueBillionUSD', 'ImportValueBillionUSD', 'UnemploymentRate',
#        'CurrentAccountDeficit'],
#       dtype='object')

# %%
eco.dtypes
# Out:
# DATE                      object
# GDPGrothRate             float64
# InflationRate            float64
# GDPBillionUSD            float64
# ExportValueBillionUSD    float64
# ImportValueBillionUSD    float64
# UnemploymentRate         float64
# CurrentAccountDeficit    float64
# dtype: object

# %% [markdown]
# **ACCESSING DATA**

# %%
eco.count()
# Out:
# DATE                     62
# GDPGrothRate             62
# InflationRate            62
# GDPBillionUSD            62
# ExportValueBillionUSD    62
# ImportValueBillionUSD    62
# UnemploymentRate         30
# CurrentAccountDeficit    62
# dtype: int64

# %%
eco.nunique()
# Out:
# DATE                     62
# GDPGrothRate             61
# InflationRate            62
# GDPBillionUSD            62
# ExportValueBillionUSD    62
# ImportValueBillionUSD    62
# UnemploymentRate         28
# CurrentAccountDeficit    62
# dtype: int64

# %%
eco.describe()
# Out:
#        GDPGrothRate  InflationRate  GDPBillionUSD  ExportValueBillionUSD  \
# count     62.000000      62.000000      62.000000              62.000000
# mean       5.019961       7.375879     699.082524             128.577156
# std        3.290171       4.908682     867.363393             189.798731
# min       -6.596100      -7.633900      37.029884               1.652702
# 25%        3.726500       4.068625     100.323715               5.887664
# 50%        5.623000       6.644550     292.125393              22.791586
# 75%        7.525375       9.883175     910.290315             190.189901
# max        9.627800      28.598700    3176.295065             679.680586
#
#        ImportValueBillionUSD  UnemploymentRate  CurrentAccountDeficit
# count              62.000000         30.000000              62.000000
# mean              148.457099          5.646233             -19.879943
# std               218.855230          0.470059              32.398145
# min                 2.337302          5.270000            -122.906095
# 25%                 6.346978          5.428250             -20.339297
# 50%                25.632725          5.574000              -4.252220
# 75%               218.400303          5.684750              -0.965146
# max               758.871890          7.997000               0.587360

# %%
eco.GDPGrothRate.value_counts()
# Out:
# 1.0568    2
# 5.4824    1
# 6.6589    1
# 7.5745    1
# 7.5495    1
#          ..
# 5.2543    1
# 4.7766    1
# 3.9654    1
# 9.6278    1
# 8.6812    1
# Name: GDPGrothRate, Length: 61, dtype: int64

# %%
eco.memory_usage()
# Out:
# Index                    128
# DATE                     496
# GDPGrothRate             496
# InflationRate            496
# GDPBillionUSD            496
# ExportValueBillionUSD    496
# ImportValueBillionUSD    496
# UnemploymentRate         496
# CurrentAccountDeficit    496
# dtype: int64

# %%
eco.memory_usage(deep=True)
# Out:
# Index                     128
# DATE                     4154
# GDPGrothRate              496
# InflationRate             496
# GDPBillionUSD             496
# ExportValueBillionUSD     496
# ImportValueBillionUSD     496
# UnemploymentRate          496
# CurrentAccountDeficit     496
# dtype: int64

# %%
eco.shape
# Out:
# (62, 8)

# %%
eco.size
# Out:
# 496

# %%
eco.ndim
# Out:
# 2

# %%
eco.GDPGrothRate.mean()
# Out:
# 5.0199612903225805

# %%
eco.GDPGrothRate.min()
# Out:
# -6.5961

# %%
eco.GDPGrothRate.max()
# Out:
# 9.6278

# %%
eco.GDPGrothRate.quantile(0.25)
# Out:
# 3.7265

# %%
eco.dtypes
# Out:
# DATE                      object
# GDPGrothRate             float64
# InflationRate            float64
# GDPBillionUSD            float64
# ExportValueBillionUSD    float64
# ImportValueBillionUSD    float64
# UnemploymentRate         float64
# CurrentAccountDeficit    float64
# dtype: object

# %%
eco.GDPGrothRate.nsmallest(3)
# Out:
# 60   -6.5961
# 19   -5.2382
# 5    -2.6358
# Name: GDPGrothRate, dtype: float64

# %%
eco.GDPGrothRate.nlargest(4)
# Out:
# 28    9.6278
# 15    9.1499
# 39    8.8458
# 61    8.6812
# Name: GDPGrothRate, dtype: float64

# %%
eco.corr()
# Out:
# <ipython-input-26-12aa780896fb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   eco.corr()
#                        GDPGrothRate  InflationRate  GDPBillionUSD  \
# GDPGrothRate               1.000000      -0.006145       0.163578
# InflationRate             -0.006145       1.000000      -0.119743
# GDPBillionUSD              0.163578      -0.119743       1.000000
# ExportValueBillionUSD      0.169595      -0.104794       0.988816
# ImportValueBillionUSD      0.185376      -0.094751       0.981427
# UnemploymentRate          -0.305023      -0.101883       0.158580
# CurrentAccountDeficit     -0.258707       0.026143      -0.836910
#
#                        ExportValueBillionUSD  ImportValueBillionUSD  \
# GDPGrothRate                        0.169595               0.185376
# InflationRate                      -0.104794              -0.094751
# GDPBillionUSD                       0.988816               0.981427
# ExportValueBillionUSD               1.000000               0.997528
# ImportValueBillionUSD               0.997528               1.000000
# UnemploymentRate                    0.076137               0.053198
# CurrentAccountDeficit              -0.880159              -0.911338
#
#                        UnemploymentRate  CurrentAccountDeficit
# GDPGrothRate                  -0.305023              -0.258707
# InflationRate                 -0.101883               0.026143
# GDPBillionUSD                  0.158580              -0.836910
# ExportValueBillionUSD          0.076137              -0.880159
# ImportValueBillionUSD          0.053198              -0.911338
# UnemploymentRate               1.000000               0.071748
# CurrentAccountDeficit          0.071748               1.000000

# %%
print(eco)
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0   12/31/1960        1.0568         1.7799      37.029884
# 1   12/31/1961        3.7227         1.6952      39.232436
# 2   12/31/1962        2.9311         3.6322      42.161482
# 3   12/31/1963        5.9944         2.9462      48.421923
# 4   12/31/1964        7.4530        13.3553      56.480290
# ..         ...           ...            ...            ...
# 57  12/31/2017        6.7954         3.3282    2651.472946
# 58  12/31/2018        6.4539         3.9388    2702.929719
# 59  12/31/2019        3.7379         3.7295    2831.552223
# 60  12/31/2020       -6.5961         6.6234    2667.687952
# 61  12/31/2021        8.6812         5.1314    3176.295065
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0                1.652702               2.530503               NaN
# 1                1.688402               2.337302               NaN
# 2                1.757702               2.543103               NaN
# 3                2.072702               2.860203               NaN
# 4                2.104202               3.210903               NaN
# ..                    ...                    ...               ...
# 57             498.258561             582.017724             5.330
# 58             538.635202             640.300825             5.270
# 59             529.244936             602.314912             7.997
# 60             499.095036             509.433826             5.978
# 61             679.680586             758.871890               NaN
#
#     CurrentAccountDeficit
# 0               -0.877801
# 1               -0.648901
# 2               -0.785401
# 3               -0.787501
# 4               -1.106701
# ..                    ...
# 57             -83.759163
# 58            -101.665624
# 59             -73.069975
# 60             -10.338790
# 61             -79.191303
#
# [62 rows x 8 columns]

# %%
eco.head(8)
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
# 5  12/31/1965       -2.6358         9.4748      59.554855
# 6  12/31/1966       -0.0553        10.8018      45.865462
# 7  12/31/1967        7.8260        13.0622      50.134942
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
# 5               1.969761               3.103738               NaN
# 6               1.900000               3.060000               NaN
# 7               2.022667               2.981333               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701
# 5              -1.133977
# 6              -1.160000
# 7              -0.958667

# %%
eco.tail(8)
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 54  12/31/2014        7.4102         6.6657    2039.127446
# 55  12/31/2015        7.9963         4.9070    2103.587814
# 56  12/31/2016        8.2563         4.9482    2294.797981
# 57  12/31/2017        6.7954         3.3282    2651.472946
# 58  12/31/2018        6.4539         3.9388    2702.929719
# 59  12/31/2019        3.7379         3.7295    2831.552223
# 60  12/31/2020       -6.5961         6.6234    2667.687952
# 61  12/31/2021        8.6812         5.1314    3176.295065
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 54             468.346038             529.239679             5.435
# 55             416.787833             465.097475             5.423
# 56             439.642788             480.169285             5.358
# 57             498.258561             582.017724             5.330
# 58             538.635202             640.300825             5.270
# 59             529.244936             602.314912             7.997
# 60             499.095036             509.433826             5.978
# 61             679.680586             758.871890               NaN
#
#     CurrentAccountDeficit
# 54             -60.893642
# 55             -48.309642
# 56             -40.526497
# 57             -83.759163
# 58            -101.665624
# 59             -73.069975
# 60             -10.338790
# 61             -79.191303

# %%
eco[:20]
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0   12/31/1960        1.0568         1.7799      37.029884
# 1   12/31/1961        3.7227         1.6952      39.232436
# 2   12/31/1962        2.9311         3.6322      42.161482
# 3   12/31/1963        5.9944         2.9462      48.421923
# 4   12/31/1964        7.4530        13.3553      56.480290
# 5   12/31/1965       -2.6358         9.4748      59.554855
# 6   12/31/1966       -0.0553        10.8018      45.865462
# 7   12/31/1967        7.8260        13.0622      50.134942
# 8   12/31/1968        3.3879         3.2374      53.085456
# 9   12/31/1969        6.5397        -0.5841      58.447995
# 10  12/31/1970        5.1572         5.0923      62.422483
# 11  12/31/1971        1.6429         3.0799      67.350988
# 12  12/31/1972       -0.5533         6.4421      71.463194
# 13  12/31/1973        3.2955        16.9408      85.515270
# 14  12/31/1974        1.1853        28.5987      99.525899
# 15  12/31/1975        9.1499         5.7484      98.472796
# 16  12/31/1976        1.6631        -7.6339     102.717164
# 17  12/31/1977        7.2548         8.3075     121.487322
# 18  12/31/1978        5.7125         2.5230     137.300295
# 19  12/31/1979       -5.2382         6.2757     152.991654
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0                1.652702               2.530503               NaN
# 1                1.688402               2.337302               NaN
# 2                1.757702               2.543103               NaN
# 3                2.072702               2.860203               NaN
# 4                2.104202               3.210903               NaN
# 5                1.969761               3.103738               NaN
# 6                1.900000               3.060000               NaN
# 7                2.022667               2.981333               NaN
# 8                2.144000               2.624000               NaN
# 9                2.170667               2.356000               NaN
# 10               2.361333               2.421333               NaN
# 11               2.469899               2.695657               NaN
# 12               2.878172               2.650506               NaN
# 13               3.599135               4.039171               NaN
# 14               4.808416               5.992026               NaN
# 15               5.560820               6.545404               NaN
# 16               6.868196               6.280836               NaN
# 17               7.754745               7.611095               NaN
# 18               8.670274               9.045600               NaN
# 19              10.326383              12.498143               NaN
#
#     CurrentAccountDeficit
# 0               -0.877801
# 1               -0.648901
# 2               -0.785401
# 3               -0.787501
# 4               -1.106701
# 5               -1.133977
# 6               -1.160000
# 7               -0.958667
# 8               -0.480000
# 9               -0.185333
# 10              -0.060000
# 11              -0.225758
# 12               0.227667
# 13              -0.440036
# 14              -1.183610
# 15              -0.984584
# 16               0.587360
# 17               0.143650
# 18              -0.375326
# 19              -2.171760

# %%
eco[:]
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0   12/31/1960        1.0568         1.7799      37.029884
# 1   12/31/1961        3.7227         1.6952      39.232436
# 2   12/31/1962        2.9311         3.6322      42.161482
# 3   12/31/1963        5.9944         2.9462      48.421923
# 4   12/31/1964        7.4530        13.3553      56.480290
# ..         ...           ...            ...            ...
# 57  12/31/2017        6.7954         3.3282    2651.472946
# 58  12/31/2018        6.4539         3.9388    2702.929719
# 59  12/31/2019        3.7379         3.7295    2831.552223
# 60  12/31/2020       -6.5961         6.6234    2667.687952
# 61  12/31/2021        8.6812         5.1314    3176.295065
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0                1.652702               2.530503               NaN
# 1                1.688402               2.337302               NaN
# 2                1.757702               2.543103               NaN
# 3                2.072702               2.860203               NaN
# 4                2.104202               3.210903               NaN
# ..                    ...                    ...               ...
# 57             498.258561             582.017724             5.330
# 58             538.635202             640.300825             5.270
# 59             529.244936             602.314912             7.997
# 60             499.095036             509.433826             5.978
# 61             679.680586             758.871890               NaN
#
#     CurrentAccountDeficit
# 0               -0.877801
# 1               -0.648901
# 2               -0.785401
# 3               -0.787501
# 4               -1.106701
# ..                    ...
# 57             -83.759163
# 58            -101.665624
# 59             -73.069975
# 60             -10.338790
# 61             -79.191303
#
# [62 rows x 8 columns]

# %%
eco[-30:]
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 32  12/31/1992        5.4824        11.7878     288.208430
# 33  12/31/1993        4.7508         6.3269     279.296023
# 34  12/31/1994        6.6589        10.2479     327.275584
# 35  12/31/1995        7.5745        10.2249     360.281953
# 36  12/31/1996        7.5495         8.9772     392.897054
# 37  12/31/1997        4.0498         7.1643     415.867754
# 38  12/31/1998        6.1844        13.2308     421.351478
# 39  12/31/1999        8.8458         4.6698     458.820417
# 40  12/31/2000        3.8410         4.0094     468.394937
# 41  12/31/2001        4.8240         3.7793     485.441015
# 42  12/31/2002        3.8040         4.2972     514.937949
# 43  12/31/2003        7.8604         3.8059     607.699285
# 44  12/31/2004        7.9229         3.7673     709.148515
# 45  12/31/2005        7.9234         4.2463     820.381596
# 46  12/31/2006        8.0607         5.7965     940.259889
# 47  12/31/2007        7.6608         6.3729    1216.735442
# 48  12/31/2008        3.0867         8.3493    1198.895582
# 49  12/31/2009        7.8619        10.8824    1341.886603
# 50  12/31/2010        8.4976        11.9894    1675.615336
# 51  12/31/2011        5.2413         8.9118    1823.049928
# 52  12/31/2012        5.4564         9.4790    1827.637860
# 53  12/31/2013        6.3861        10.0179    1856.722121
# 54  12/31/2014        7.4102         6.6657    2039.127446
# 55  12/31/2015        7.9963         4.9070    2103.587814
# 56  12/31/2016        8.2563         4.9482    2294.797981
# 57  12/31/2017        6.7954         3.3282    2651.472946
# 58  12/31/2018        6.4539         3.9388    2702.929719
# 59  12/31/2019        3.7379         3.7295    2831.552223
# 60  12/31/2020       -6.5961         6.6234    2667.687952
# 61  12/31/2021        8.6812         5.1314    3176.295065
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 32              25.486061              27.639685             5.691
# 33              27.466578              27.419391             5.739
# 34              32.361288              33.349577             5.755
# 35              39.068860              43.318431             5.740
# 36              40.803024              45.357288             5.613
# 37              44.459246              49.607490             5.666
# 38              46.426483              53.431585             5.736
# 39              52.544411              61.314620             5.561
# 40              60.878397              65.124164             5.576
# 41              60.963526              65.218394             5.530
# 42              73.452726              78.498578             5.643
# 43              90.838366              95.071650             5.629
# 44             126.647719             139.310021             5.613
# 45             160.837836             183.736132             5.601
# 46             199.973922             229.955027             5.572
# 47             253.077319             302.803704             5.414
# 48             288.902152             350.927086             5.544
# 49             273.751836             347.177602             5.546
# 50             375.353473             449.974321             5.426
# 51             447.383951             566.667154             5.414
# 52             448.400543             571.306638             5.424
# 53             472.180427             527.555481             5.436
# 54             468.346038             529.239679             5.435
# 55             416.787833             465.097475             5.423
# 56             439.642788             480.169285             5.358
# 57             498.258561             582.017724             5.330
# 58             538.635202             640.300825             5.270
# 59             529.244936             602.314912             7.997
# 60             499.095036             509.433826             5.978
# 61             679.680586             758.871890               NaN
#
#     CurrentAccountDeficit
# 32              -2.153624
# 33               0.047187
# 34              -0.988289
# 35              -4.249571
# 36              -4.554264
# 37              -5.148244
# 38              -7.005102
# 39              -8.770209
# 40              -4.245767
# 41              -4.254869
# 42              -5.045852
# 43              -4.233284
# 44             -12.662302
# 45             -22.898296
# 46             -29.981105
# 47             -49.726386
# 48             -62.024934
# 49             -73.425766
# 50             -74.620848
# 51            -119.283203
# 52            -122.906095
# 53             -55.375054
# 54             -60.893642
# 55             -48.309642
# 56             -40.526497
# 57             -83.759163
# 58            -101.665624
# 59             -73.069975
# 60             -10.338790
# 61             -79.191303

# %%
eco[60:21]
# Out:
# Empty DataFrame
# Columns: [DATE, GDPGrothRate, InflationRate, GDPBillionUSD, ExportValueBillionUSD, ImportValueBillionUSD, UnemploymentRate, CurrentAccountDeficit]
# Index: []

# %%
eco['GDPGrothRate']
# Out:
# 0     1.0568
# 1     3.7227
# 2     2.9311
# 3     5.9944
# 4     7.4530
#        ...
# 57    6.7954
# 58    6.4539
# 59    3.7379
# 60   -6.5961
# 61    8.6812
# Name: GDPGrothRate, Length: 62, dtype: float64

# %%
eco.isnull()
# Out:
#      DATE  GDPGrothRate  InflationRate  GDPBillionUSD  ExportValueBillionUSD  \
# 0   False         False          False          False                  False
# 1   False         False          False          False                  False
# 2   False         False          False          False                  False
# 3   False         False          False          False                  False
# 4   False         False          False          False                  False
# ..    ...           ...            ...            ...                    ...
# 57  False         False          False          False                  False
# 58  False         False          False          False                  False
# 59  False         False          False          False                  False
# 60  False         False          False          False                  False
# 61  False         False          False          False                  False
#
#     ImportValueBillionUSD  UnemploymentRate  CurrentAccountDeficit
# 0                   False              True                  False
# 1                   False              True                  False
# 2                   False              True                  False
# 3                   False              True                  False
# 4                   False              True                  False
# ..                    ...               ...                    ...
# 57                  False             False                  False
# 58                  False             False                  False
# 59                  False             False                  False
# 60                  False             False                  False
# 61                  False              True                  False
#
# [62 rows x 8 columns]

# %%
eco.isnull().all()
# Out:
# DATE                     False
# GDPGrothRate             False
# InflationRate            False
# GDPBillionUSD            False
# ExportValueBillionUSD    False
# ImportValueBillionUSD    False
# UnemploymentRate         False
# CurrentAccountDeficit    False
# dtype: bool

# %%
eco.isnull().sum()
# Out:
# DATE                      0
# GDPGrothRate              0
# InflationRate             0
# GDPBillionUSD             0
# ExportValueBillionUSD     0
# ImportValueBillionUSD     0
# UnemploymentRate         32
# CurrentAccountDeficit     0
# dtype: int64

# %%
eco.fillna('Not_Define')
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0   12/31/1960        1.0568         1.7799      37.029884
# 1   12/31/1961        3.7227         1.6952      39.232436
# 2   12/31/1962        2.9311         3.6322      42.161482
# 3   12/31/1963        5.9944         2.9462      48.421923
# 4   12/31/1964        7.4530        13.3553      56.480290
# ..         ...           ...            ...            ...
# 57  12/31/2017        6.7954         3.3282    2651.472946
# 58  12/31/2018        6.4539         3.9388    2702.929719
# 59  12/31/2019        3.7379         3.7295    2831.552223
# 60  12/31/2020       -6.5961         6.6234    2667.687952
# 61  12/31/2021        8.6812         5.1314    3176.295065
#
#     ExportValueBillionUSD  ImportValueBillionUSD UnemploymentRate  \
# 0                1.652702               2.530503       Not_Define
# 1                1.688402               2.337302       Not_Define
# 2                1.757702               2.543103       Not_Define
# 3                2.072702               2.860203       Not_Define
# 4                2.104202               3.210903       Not_Define
# ..                    ...                    ...              ...
# 57             498.258561             582.017724             5.33
# 58             538.635202             640.300825             5.27
# 59             529.244936             602.314912            7.997
# 60             499.095036             509.433826            5.978
# 61             679.680586             758.871890       Not_Define
#
#     CurrentAccountDeficit
# 0               -0.877801
# 1               -0.648901
# 2               -0.785401
# 3               -0.787501
# 4               -1.106701
# ..                    ...
# 57             -83.759163
# 58            -101.665624
# 59             -73.069975
# 60             -10.338790
# 61             -79.191303
#
# [62 rows x 8 columns]

# %%
eco.isna().any
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of      DATE  GDPGrothRate  InflationRate  GDPBillionUSD  ExportValueBillionUSD  \
# 0   False         False          False          False                  False
# 1   False         False          False          False                  False
# 2   False         False          False          False                  False
# 3   False         False          False          False                  False
# 4   False         False          False          False                  False
# ..    ...           ...            ...            ...                    ...
# 57  False         False          False          False                  False
# 58  False         False          False          False                  False
# 59  False         False          False          False                  False
# 60  False         False          False          False                  False
# 61  False         False          False          False                  False
#
#     ImportValueBillionUSD  UnemploymentRate  CurrentAccountDeficit
# 0                   False              True                  False
# 1                   False              True                  False
# 2                   False              True                  False
# 3                   False              True                  False
# 4                   False              True                  False
# ..                    ...               ...                    ...
# 57                  False             False                  False
# 58                  False             False                  False
# 59                  False             False                  False
# 60                  False             False                  False
# 61                  False              True                  False
#
# [62 rows x 8 columns]>

# %%
eco.isna().all()
# Out:
# DATE                     False
# GDPGrothRate             False
# InflationRate            False
# GDPBillionUSD            False
# ExportValueBillionUSD    False
# ImportValueBillionUSD    False
# UnemploymentRate         False
# CurrentAccountDeficit    False
# dtype: bool

# %% [markdown]
# **DATA VISUALIZATION**

# %%
plt.scatter(eco.GDPGrothRate,eco.InflationRate,eco.GDPBillionUSD,eco.ImportValueBillionUSD)
plt.show()

# %%
sns.heatmap(eco.corr())
# Out:
# <ipython-input-30-59368a85688f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(eco.corr())
# <Axes: >

# %%
sns.heatmap(eco.corr(),annot=True)
# Out:
# <ipython-input-31-356f8dd5a122>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(eco.corr(),annot=True)
# <Axes: >

# %%
sns.heatmap(eco.corr(),annot=True,cmap='Blues')
# Out:
# <ipython-input-32-620c546df06f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(eco.corr(),annot=True,cmap='Blues')
# <Axes: >

# %%
sns.heatmap(eco.corr(),annot=True,cmap='rainbow')
# Out:
# <ipython-input-33-b8b2b3c457e9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(eco.corr(),annot=True,cmap='rainbow')
# <Axes: >

# %%
plt.scatter(eco.GDPGrothRate,eco.InflationRate,eco.GDPBillionUSD,eco.ImportValueBillionUSD)
plt.title("Economic Growth")
sns.set()
plt.show()

# %%
# Extra visualization
# relplot show the relationship between two variables with semantic mappings of subsets
# by default relplot type is scatter we can change to line ------- kind=line)
sns.relplot(data=eco, x="GDPBillionUSD", y="ImportValueBillionUSD")

# %%
sns.relplot(data=eco, x="GDPBillionUSD", y="ImportValueBillionUSD", hue="GDPGrothRate")

# %%
sns.relplot(data=eco, x="GDPBillionUSD", y="ImportValueBillionUSD", hue="GDPGrothRate",col="InflationRate",col_wrap=3)

# %%
sns.set_context("poster")
sns.relplot(data=eco, x="GDPBillionUSD", y="ImportValueBillionUSD", kind="line", ci=None)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
import seaborn as sns
from matplotlib import pyplot as plt
eco=pd.read_csv("AIMLPROJECT.csv")
sns.set_style("ticks")
sns.pairplot(eco, hue="GDPBillionUSD", diag_kind="ImportValueBillionUSD", kind="scatter", palette="husl")
plt.show()

# %%
sns.pointplot( x="GDPBillionUSD", y="ImportValueBillionUSD", data=eco)
plt.show()

# %%
SA=pd.read_csv("AIMLPROJECT.csv")
SA.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
# Add regression line to scatter plot and kernel density estimate to histogram
sns.jointplot(x='GDPBillionUSD', y='ImportValueBillionUSD', data=SA, kind='reg')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1760: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
sns.jointplot(x='GDPBillionUSD', y='ImportValueBillionUSD', data=SA, kind='kde')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1760: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
# Display hexagons instead of points in scatter plot

sns.jointplot(x='GDPBillionUSD', y='ImportValueBillionUSD', data=SA, kind='hex')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1760: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
#A box plot is composed of a summary of 5 different data points: the minimum, first quartil
#sns.boxplot(x='Temperature', y='Revenue', data=SA)
ax = sns.boxplot(x=SA['GDPBillionUSD'])

# %%
ax = sns.violinplot(x=SA['GDPGrothRate'])

# %%
ax = sns.violinplot(x=SA['GDPBillionUSD'])

# %%
ax = sns.regplot(x='GDPGrothRate', y='GDPBillionUSD', data=SA,ci=None)

# %%
sns.lmplot(x='GDPBillionUSD', y='InflationRate', data=SA)

# %%
eco.count().plot.bar()
# Out:
# <Axes: >

# %%
eco.count().plot.barh()
# Out:
# <Axes: >

# %%
eco.GDPGrothRate.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
SA=pd.read_csv("AIMLPROJECT.csv")
SA.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
sns.jointplot(x='GDPGrothRate', y='InflationRate', data=SA, kind='reg')

# %%
sns.jointplot(x='GDPGrothRate', y='InflationRate', data=SA, kind='kde')

# %%
sns.jointplot(x='GDPGrothRate', y='InflationRate', data=SA, kind='hex')

# %%
ax = sns.boxplot(x=SA['GDPGrothRate'])

# %%
ax = sns.boxplot(x=SA['InflationRate'])

# %%
ax = sns.boxplot(x=SA['GDPBillionUSD'])

# %%
ax = sns.boxplot(x=SA['ExportValueBillionUSD'])

# %%
ax = sns.boxplot(x=SA['ImportValueBillionUSD'])

# %%
ax = sns.boxplot(x=SA['CurrentAccountDeficit'])

# %%
ax = sns.regplot(x='GDPGrothRate', y='InflationRate', data=SA,ci=None)

# %%
sns.lmplot(x='GDPGrothRate', y='InflationRate', data=SA)

# %%
y = eco['GDPGrothRate']
X = eco[['InflationRate']]

# %%
X
# Out:
#     InflationRate
# 0          1.7799
# 1          1.6952
# 2          3.6322
# 3          2.9462
# 4         13.3553
# ..            ...
# 57         3.3282
# 58         3.9388
# 59         3.7295
# 60         6.6234
# 61         5.1314
#
# [62 rows x 1 columns]

# %% [markdown]
# **LINEAR REGRESSION **

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.shape # size of training dataset
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m): ', regressor.coef_)
print('Linear Model Coefficient (b): ', regressor.intercept_)
# Out:
# Linear Model Coefficient (m):  [-0.01147738]
# Linear Model Coefficient (b):  5.001974945936309

# %%
y_predict = regressor.predict( X_test)
y_predict
# Out:
# array([4.8657603 , 4.9359984 , 4.9825185 , 4.9254702 , 4.95917007,
#        4.9582932 , 4.95873623, 4.95676786, 4.89322911, 4.92994638,
#        4.89427699, 4.8931809 , 4.87707355, 4.9681603 , 4.87175149,
#        4.95595756])

# %%
y_test
# Out:
# 23    7.2889
# 15    9.1499
# 1     3.7227
# 54    7.4102
# 59    3.7379
# 43    7.8604
# 44    7.9229
# 58    6.4539
# 5    -2.6358
# 19   -5.2382
# 28    9.6278
# 52    5.4564
# 49    7.8619
# 3     5.9944
# 20    6.7358
# 40    3.8410
# Name: GDPGrothRate, dtype: float64

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('GDPGrothRate')
plt.xlabel('InflationRate')
plt.title('GDP GROWTH vs. INFLATION RATE @INDIAN ECONOMY SYSTEM(Training dataset)')
# Out:
# Text(0.5, 1.0, 'GDP GROWTH vs. INFLATION RATE @INDIAN ECONOMY SYSTEM(Training dataset)')

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('GDPGrothRate')
plt.xlabel('GDPBillionUSD')
plt.title('GDP GROWTH vs. GDPBillionUSD @INDIAN ECONOMY SYSTEM(Training dataset)')
# Out:
# Text(0.5, 1.0, 'GDP GROWTH vs. GDPBillionUSD @INDIAN ECONOMY SYSTEM(Training dataset)')

# %%
# Display Performance metrics, SLope and Intercept

import sklearn.metrics as metrics

wts = regressor.coef_
incpt = regressor.intercept_
print("Slope :",wts,"\n\nIntercept ",incpt,"\n")
print('Mean Absolute Error-MAE', metrics.mean_absolute_error(y_test,y_predict),"\n")
print("Mean Square Error-MSE : ", metrics.mean_squared_error(y_test, y_predict),"\n")
print('Root Mean Square Error- RMSE :', np.sqrt(metrics.mean_squared_error(y_test, y_predict)),"\n")
print('R2 score  :', metrics.r2_score(y_test, y_predict),"\n")
# Out:
# Slope : [-0.01147738]
#
# Intercept  5.001974945936309
#
# Mean Absolute Error-MAE 3.0593907615985096
#
# Mean Square Error-MSE :  15.613255839024342
#
# Root Mean Square Error- RMSE : 3.951361264048675
#
# R2 score  : -0.011645990486744306

# %% [markdown]
# **TESTING THE MODEL**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_test.shape
# Out:
# (16, 1)

# %%
# import the libraries
import numpy as np
import pandas as pd# import the dataset
ind = pd.read_csv('/content/AIMLPROJECT.csv')# get dummy variables

# %%
ind.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
ind.dtypes
# Out:
# DATE                      object
# GDPGrothRate             float64
# InflationRate            float64
# GDPBillionUSD            float64
# ExportValueBillionUSD    float64
# ImportValueBillionUSD    float64
# UnemploymentRate         float64
# CurrentAccountDeficit    float64
# dtype: object

# %%
ind_getdummy=pd.get_dummies(data=ind,columns=['GDPGrothRate'])
X=ind_getdummy.drop('UnemploymentRate',axis=1)
y=ind_getdummy['UnemploymentRate']

# %%
X
# Out:
#           DATE  InflationRate  GDPBillionUSD  ExportValueBillionUSD  \
# 0   12/31/1960         1.7799      37.029884               1.652702
# 1   12/31/1961         1.6952      39.232436               1.688402
# 2   12/31/1962         3.6322      42.161482               1.757702
# 3   12/31/1963         2.9462      48.421923               2.072702
# 4   12/31/1964        13.3553      56.480290               2.104202
# ..         ...            ...            ...                    ...
# 57  12/31/2017         3.3282    2651.472946             498.258561
# 58  12/31/2018         3.9388    2702.929719             538.635202
# 59  12/31/2019         3.7295    2831.552223             529.244936
# 60  12/31/2020         6.6234    2667.687952             499.095036
# 61  12/31/2021         5.1314    3176.295065             679.680586
#
#     ImportValueBillionUSD  CurrentAccountDeficit  GDPGrothRate_-6.5961  \
# 0                2.530503              -0.877801                     0
# 1                2.337302              -0.648901                     0
# 2                2.543103              -0.785401                     0
# 3                2.860203              -0.787501                     0
# 4                3.210903              -1.106701                     0
# ..                    ...                    ...                   ...
# 57             582.017724             -83.759163                     0
# 58             640.300825            -101.665624                     0
# 59             602.314912             -73.069975                     0
# 60             509.433826             -10.338790                     1
# 61             758.871890             -79.191303                     0
#
#     GDPGrothRate_-5.2382  GDPGrothRate_-2.6358  GDPGrothRate_-0.5533  ...  \
# 0                      0                     0                     0  ...
# 1                      0                     0                     0  ...
# 2                      0                     0                     0  ...
# 3                      0                     0                     0  ...
# 4                      0                     0                     0  ...
# ..                   ...                   ...                   ...  ...
# 57                     0                     0                     0  ...
# 58                     0                     0                     0  ...
# 59                     0                     0                     0  ...
# 60                     0                     0                     0  ...
# 61                     0                     0                     0  ...
#
#     GDPGrothRate_7.9229  GDPGrothRate_7.9234  GDPGrothRate_7.9963  \
# 0                     0                    0                    0
# 1                     0                    0                    0
# 2                     0                    0                    0
# 3                     0                    0                    0
# 4                     0                    0                    0
# ..                  ...                  ...                  ...
# 57                    0                    0                    0
# 58                    0                    0                    0
# 59                    0                    0                    0
# 60                    0                    0                    0
# 61                    0                    0                    0
#
#     GDPGrothRate_8.0607  GDPGrothRate_8.2563  GDPGrothRate_8.4976  \
# 0                     0                    0                    0
# 1                     0                    0                    0
# 2                     0                    0                    0
# 3                     0                    0                    0
# 4                     0                    0                    0
# ..                  ...                  ...                  ...
# 57                    0                    0                    0
# 58                    0                    0                    0
# 59                    0                    0                    0
# 60                    0                    0                    0
# 61                    0                    0                    0
#
#     GDPGrothRate_8.6812  GDPGrothRate_8.8458  GDPGrothRate_9.1499  \
# 0                     0                    0                    0
# 1                     0                    0                    0
# 2                     0                    0                    0
# 3                     0                    0                    0
# 4                     0                    0                    0
# ..                  ...                  ...                  ...
# 57                    0                    0                    0
# 58                    0                    0                    0
# 59                    0                    0                    0
# 60                    0                    0                    0
# 61                    1                    0                    0
#
#     GDPGrothRate_9.6278
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 57                    0
# 58                    0
# 59                    0
# 60                    0
# 61                    0
#
# [62 rows x 67 columns]

# %%
y
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#       ...
# 57    5.330
# 58    5.270
# 59    7.997
# 60    5.978
# 61      NaN
# Name: UnemploymentRate, Length: 62, dtype: float64

# %%
ind.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
ind[35:50]
# Out:
#           DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 35  12/31/1995        7.5745        10.2249     360.281953
# 36  12/31/1996        7.5495         8.9772     392.897054
# 37  12/31/1997        4.0498         7.1643     415.867754
# 38  12/31/1998        6.1844        13.2308     421.351478
# 39  12/31/1999        8.8458         4.6698     458.820417
# 40  12/31/2000        3.8410         4.0094     468.394937
# 41  12/31/2001        4.8240         3.7793     485.441015
# 42  12/31/2002        3.8040         4.2972     514.937949
# 43  12/31/2003        7.8604         3.8059     607.699285
# 44  12/31/2004        7.9229         3.7673     709.148515
# 45  12/31/2005        7.9234         4.2463     820.381596
# 46  12/31/2006        8.0607         5.7965     940.259889
# 47  12/31/2007        7.6608         6.3729    1216.735442
# 48  12/31/2008        3.0867         8.3493    1198.895582
# 49  12/31/2009        7.8619        10.8824    1341.886603
#
#     ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 35              39.068860              43.318431             5.740
# 36              40.803024              45.357288             5.613
# 37              44.459246              49.607490             5.666
# 38              46.426483              53.431585             5.736
# 39              52.544411              61.314620             5.561
# 40              60.878397              65.124164             5.576
# 41              60.963526              65.218394             5.530
# 42              73.452726              78.498578             5.643
# 43              90.838366              95.071650             5.629
# 44             126.647719             139.310021             5.613
# 45             160.837836             183.736132             5.601
# 46             199.973922             229.955027             5.572
# 47             253.077319             302.803704             5.414
# 48             288.902152             350.927086             5.544
# 49             273.751836             347.177602             5.546
#
#     CurrentAccountDeficit
# 35              -4.249571
# 36              -4.554264
# 37              -5.148244
# 38              -7.005102
# 39              -8.770209
# 40              -4.245767
# 41              -4.254869
# 42              -5.045852
# 43              -4.233284
# 44             -12.662302
# 45             -22.898296
# 46             -29.981105
# 47             -49.726386
# 48             -62.024934
# 49             -73.425766

# %%
ind.isnull().sum()
# Out:
# DATE                      0
# GDPGrothRate              0
# InflationRate             0
# GDPBillionUSD             0
# ExportValueBillionUSD     0
# ImportValueBillionUSD     0
# UnemploymentRate         32
# CurrentAccountDeficit     0
# dtype: int64

# %%
ind.shape
# Out:
# (62, 8)

# %%
ind.describe()
# Out:
#        GDPGrothRate  InflationRate  GDPBillionUSD  ExportValueBillionUSD  \
# count     62.000000      62.000000      62.000000              62.000000
# mean       5.019961       7.375879     699.082524             128.577156
# std        3.290171       4.908682     867.363393             189.798731
# min       -6.596100      -7.633900      37.029884               1.652702
# 25%        3.726500       4.068625     100.323715               5.887664
# 50%        5.623000       6.644550     292.125393              22.791586
# 75%        7.525375       9.883175     910.290315             190.189901
# max        9.627800      28.598700    3176.295065             679.680586
#
#        ImportValueBillionUSD  UnemploymentRate  CurrentAccountDeficit
# count              62.000000         30.000000              62.000000
# mean              148.457099          5.646233             -19.879943
# std               218.855230          0.470059              32.398145
# min                 2.337302          5.270000            -122.906095
# 25%                 6.346978          5.428250             -20.339297
# 50%                25.632725          5.574000              -4.252220
# 75%               218.400303          5.684750              -0.965146
# max               758.871890          7.997000               0.587360

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ind.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
sns.countplot(ind['GDPGrothRate'], palette = 'Set2')
plt.title ('GDPGrothRate vs. Quantity', fontsize = 10)
plt.show()

# %%
ind.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
ind.shape
# Out:
# (62, 8)

# %%
ind. drop('CurrentAccountDeficit', axis=1, inplace=True)

# %%
ind.shape
# Out:
# (62, 7)

# %%
ind.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN

# %%
sns.set_context("paper")
sns.scatterplot(x='GDPGrothRate', y='InflationRate', data=ind, hue='GDPBillionUSD')
# Out:
# <Axes: xlabel='GDPGrothRate', ylabel='InflationRate'>

# %%
sns.set_context("poster")
sns.relplot(data=ind, x="GDPGrothRate", y="InflationRate", hue="GDPBillionUSD")

# %%
sns.set_style("ticks")
sns.pairplot(ind,hue = 'GDPGrothRate',diag_kind = "InflationRate",kind = "scatter",
 palette = "husl")
plt.show()

# %%
sns.distplot(ind['GDPGrothRate'], bins = 10, color = 'green', label = 'KDE')
plt.legend()
plt.gcf().set_size_inches(12, 5)
# Out:
# <ipython-input-51-e2e7bcb1f2da>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ind['GDPGrothRate'], bins = 10, color = 'green', label = 'KDE')

# %%
X.drop('CurrentAccountDeficit',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a3ac8e735178> in <cell line: 1>()
# ----> 1 X.drop('CurrentAccountDeficit',axis=1,inplace=True)
#
# NameError: name 'X' is not defined

# %%
# split the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state =0)

# %%
y
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#       ...
# 57    5.330
# 58    5.270
# 59    7.997
# 60    5.978
# 61      NaN
# Name: UnemploymentRate, Length: 62, dtype: float64

# %%
# Scale the data set
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
ds=pd.read_csv('/content/AIMLPROJECT.csv')
ds.head()
# Out:
#          DATE  GDPGrothRate  InflationRate  GDPBillionUSD  \
# 0  12/31/1960        1.0568         1.7799      37.029884
# 1  12/31/1961        3.7227         1.6952      39.232436
# 2  12/31/1962        2.9311         3.6322      42.161482
# 3  12/31/1963        5.9944         2.9462      48.421923
# 4  12/31/1964        7.4530        13.3553      56.480290
#
#    ExportValueBillionUSD  ImportValueBillionUSD  UnemploymentRate  \
# 0               1.652702               2.530503               NaN
# 1               1.688402               2.337302               NaN
# 2               1.757702               2.543103               NaN
# 3               2.072702               2.860203               NaN
# 4               2.104202               3.210903               NaN
#
#    CurrentAccountDeficit
# 0              -0.877801
# 1              -0.648901
# 2              -0.785401
# 3              -0.787501
# 4              -1.106701

# %%
#assigning independent and dependent variables
x = ds.iloc[:,2:-1].values
y = ds.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,
 random_state = 0)
